# %%
from MLE_Entregable1.processing import pie_chart, bar_plot,cloud_words,plot_word_frequency
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/local/BAUSTRO/ba01006607/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/local/BAUSTRO/ba01006607/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /home/local/BAUSTRO/ba01006607/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
word = "Frase de prueba para validar el deber final el entregable 1"

# %%
pie_chart(word)
# Out:
# ['el',
#  'Frase',
#  'de',
#  'prueba',
#  'para',
#  'validar',
#  'deber',
#  'final',
#  'entregable',
#  '1']

# %%
bar_plot(word)
# Out:
# (['el',
#   'Frase',
#   'de',
#   'prueba',
#   'para',
#   'validar',
#   'deber',
#   'final',
#   'entregable',
#   '1'],
#  array([2, 1, 1, 1, 1, 1, 1, 1, 1, 1]))

# %%
cloud_words(word)

# %%
plot_word_frequency(word)
